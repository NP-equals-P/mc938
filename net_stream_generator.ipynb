# %%
from generators.net_stream_gen.NetStreamGenerator import NetStreamGenerator

# %%
gen = NetStreamGenerator()

# %%
for i in range(25):
    seed = gen.seed
    randint = gen.get_random_float(0, 9)
    print(f" ---------- Iteração {i} ---------- ")
    print(f"seed: {seed} | número: {randint}")
    print(f"seed_indexes: {gen.seed_indexes} | index_counter: {gen.index_counter}")
# Out:
#  ---------- Iteração 0 ----------
# seed: 20217186 | número: 2.0
# seed_indexes: [-8, -4, -2, -1] | index_counter: 1
#  ---------- Iteração 1 ----------
# seed: 20217186 | número: 7.0
# seed_indexes: [-8, -4, -2, -1] | index_counter: 2
#  ---------- Iteração 2 ----------
# seed: 20217186 | número: 8.0
# seed_indexes: [-8, -4, -2, -1] | index_counter: 3
# 2 6
# 1 7
#  ---------- Iteração 3 ----------
# seed: 20217186 | número: 6.0
# seed_indexes: [6, 1, 4, 1] | index_counter: 0
#  ---------- Iteração 4 ----------
# seed: 25717131 | número: 3.0
# seed_indexes: [6, 1, 4, 1] | index_counter: 1
#  ---------- Iteração 5 ----------
# seed: 25717131 | número: 5.0
# seed_indexes: [6, 1, 4, 1] | index_counter: 2
#  ---------- Iteração 6 ----------
# seed: 25717131 | número: 7.0
# seed_indexes: [6, 1, 4, 1] | index_counter: 3
# 1 7
# 2 6
#  ---------- Iteração 7 ----------
# seed: 25717131 | número: 5.0
# seed_indexes: [7, 4, 6, 2] | index_counter: 0
#  ---------- Iteração 8 ----------
# ...

# %%
gen.seed
# Out:
# '80055971'

# %%
gen._swap_seed_digits(0, 7)
gen.seed
# Out:
# 0 7
# '00055979'
